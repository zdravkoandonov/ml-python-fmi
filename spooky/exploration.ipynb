# %% [markdown]
# # Spooky Author Identification

# %%
import pandas as pd
pd.set_option('max_columns', None)

train = pd.read_csv("data/train.zip", index_col=['id'])
test = pd.read_csv("data/test.zip", index_col=['id'])
sample_submission = pd.read_csv("data/sample_submission.zip", index_col=['id'])

print(train.shape, test.shape, sample_submission.shape)
print(set(train.columns) - set(test.columns))
# Out:
# (19579, 2) (8392, 1) (8392, 3)
# {'author'}

# %%
train.head()
# Out:
#                                                       text author
# id
# id26305  This process, however, afforded me no means of...    EAP
# id17569  It never once occurred to me that the fumbling...    HPL
# id11008  In his left hand was a gold snuff box, from wh...    EAP
# id27763  How lovely is spring As we looked from Windsor...    MWS
# id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
test.head()
# Out:
#                                                       text
# id
# id02310  Still, as I urged our leaving Ireland with suc...
# id24541  If a fire wanted fanning, it could readily be ...
# id00134  And when they had broken down the frail door t...
# id27757  While I was thinking how I should possibly man...
# id04081  I am not sure to what limit his knowledge may ...

# %%
sample_submission.head()
# Out:
#               EAP       HPL       MWS
# id
# id02310  0.403494  0.287808  0.308698
# id24541  0.403494  0.287808  0.308698
# id00134  0.403494  0.287808  0.308698
# id27757  0.403494  0.287808  0.308698
# id04081  0.403494  0.287808  0.308698

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import cross_val_score

# %%
pipeline = Pipeline([
    ('features', CountVectorizer()),
    ('clf', LinearSVC())
])

cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3)
# Out:
# array([ 0.78783701,  0.79635305,  0.79509579])

# %%
from sklearn.ensemble import RandomForestClassifier
pipeline = Pipeline([
    ('features', CountVectorizer()),
    ('clf', RandomForestClassifier())
])

cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3)
# Out:
# array([ 0.61259191,  0.61630401,  0.60781609])

# %%
cross_val_score(pipeline, train.text, train.author, 
                cv=3, n_jobs=3, scoring='neg_log_loss')
# Out:
# array([-1.47875413, -1.27711926, -1.40480171])

# %%
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    ('features', CountVectorizer()),
    ('clf', LogisticRegression())
])

print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3))
print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3, 
                      scoring='neg_log_loss'))
# Out:
# [ 0.81449142  0.81673307  0.81348659]
# [-0.47678328 -0.47558895 -0.47131481]

# %%
import nltk
# nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
print(len(stopwords))
print(stopwords)
# Out:
# 153
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer

params_count_word = {"features__ngram_range": [(1,1), (1,2), (1,3)],
                      "features__analyzer": ['word'],
                      "features__max_df":[1.0, 0.9, 0.8, 0.7, 0.6, 0.5],
                      "features__min_df":[2, 3, 5, 10],
                      "features__lowercase": [False, True],
                      "features__stop_words": [None, stopwords]}

params_count_char = {"features__ngram_range": [(1,4), (1,5), (1,6)],
                      "features__analyzer": ['char'],
                      "features__max_df":[1.0, 0.9, 0.8, 0.7, 0.6, 0.5],
                      "features__min_df":[2, 3, 5, 10],
                      "features__lowercase": [False, True],
                      "features__stop_words": [None, stopwords]}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9367d411f764> in <module>()
#       6                       "features__min_df":[2, 3, 5, 10],
#       7                       "features__lowercase": [False, True],
# ----> 8                       "features__stop_words": [None, stopwords]}
#       9
#      10 params_count_char = {"features__ngram_range": [(1,4), (1,5), (1,6)],
#
# NameError: name 'stopwords' is not defined

# %%
import numpy as np

def report(results, n_top=5):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import log_loss
def random_search():
    params = {
        "clf__C": [0.01, 0.1, 0.3, 1, 3, 10],
        "clf__class_weight": [None, 'balanced']
    }

    params.update(params_count_word)

    pipeline = Pipeline([
        ('features', CountVectorizer()),
        ('clf', LogisticRegression())
    ])

    random_search = RandomizedSearchCV(pipeline, param_distributions=params, 
                                       scoring='neg_log_loss',
                                       n_iter=20, cv=3, n_jobs=4)

    random_search.fit(train.text, train.author)
    report(random_search.cv_results_)

# random_search()

# %%
from sklearn.naive_bayes import MultinomialNB

def random_search():
    params = {
        "clf__alpha": [0.01, 0.1, 0.5, 1, 2]
    }

    params.update(params_count_word)

    pipeline = Pipeline([
        ('features', TfidfVectorizer()),
        ('clf', MultinomialNB())
    ])

    random_search = RandomizedSearchCV(pipeline, param_distributions=params, 
                                       scoring='neg_log_loss',
                                       n_iter=20, cv=3, n_jobs=4)

    random_search.fit(train.text, train.author)
    report(random_search.cv_results_)

# random_search()  # Предишния най-добър резултат: -0.469

# %%
explore = train.copy()

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

stem = PorterStemmer()

explore['stemmed'] = explore.text.apply(lambda t: " ".join([stem.stem(w) for w in t.split()]))

# %%
def random_search():
    params = {
        "clf__alpha": [0.001, 0.005, 0.01, 0.05, 0.1, 0.3]
    }

    params.update(params_count_word)

    pipeline = Pipeline([
        ('features', TfidfVectorizer()),
        ('clf', MultinomialNB())
    ])

    random_search = RandomizedSearchCV(pipeline, param_distributions=params, 
                                       scoring='neg_log_loss',
                                       n_iter=20, cv=3, n_jobs=4)

    random_search.fit(explore.stemmed, train.author)
    report(random_search.cv_results_)
    
random_search()  # -0.423
# Out:
# Model with rank: 1
# Mean validation score: -0.426 (std: 0.003)
# Parameters: {'features__max_df': 1.0, 'features__stop_words': None, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__lowercase': True, 'features__ngram_range': (1, 3), 'features__analyzer': 'word'}
#
# Model with rank: 2
# Mean validation score: -0.435 (std: 0.003)
# Parameters: {'features__max_df': 1.0, 'features__stop_words': None, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__lowercase': False, 'features__ngram_range': (1, 2), 'features__analyzer': 'word'}
#
# Model with rank: 3
# Mean validation score: -0.450 (std: 0.004)
# Parameters: {'features__max_df': 0.7, 'features__stop_words': None, 'clf__alpha': 0.1, 'features__min_df': 3, 'features__lowercase': False, 'features__ngram_range': (1, 2), 'features__analyzer': 'word'}
#
# Model with rank: 4
# Mean validation score: -0.450 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'features__stop_words': None, 'clf__alpha': 0.01, 'features__min_df': 3, 'features__lowercase': True, 'features__ngram_range': (1, 2), 'features__analyzer': 'word'}
#
# Model with rank: 5
# Mean validation score: -0.474 (std: 0.005)
# Parameters: {'features__max_df': 1.0, 'features__stop_words': ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn'], 'clf__alpha': 0.1, 'features__min_df': 2, 'features__lowercase': True, 'features__ngram_range': (1, 2), 'features__analyzer': 'word'}

# %%
pipeline = Pipeline([
    ('features', TfidfVectorizer(ngram_range=(1, 2), min_df=2,
                                 max_df=0.8, lowercase=False)),
    ('clf', MultinomialNB(alpha=0.01))
])

print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3))
print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3, 
                      scoring='neg_log_loss'))
# Out:
# [ 0.83195466  0.83466135  0.83187739]
# [-0.42530307 -0.418245   -0.42500535]

# %% [markdown]
# Да пробваме с най-добрите параметри, които сегашното пускане на Random Search намери:

# %%
pipeline = Pipeline([
    ('features', TfidfVectorizer(ngram_range=(1, 3), min_df=2,
                                 max_df=0.5, lowercase=False, analyzer='word')),
    ('clf', MultinomialNB(alpha=0.1))
])

print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3))
print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3, 
                      scoring='neg_log_loss'))
# Out:
# [ 0.83838848  0.84171008  0.84337165]
# [-0.42373207 -0.42124757 -0.41789195]

# %%
import time
from sklearn.model_selection import GridSearchCV
def grid_search(text, params):
    pipeline = Pipeline([
        ('features', TfidfVectorizer()),
        ('clf', MultinomialNB())
    ])

    search = GridSearchCV(pipeline, param_grid=params, 
                                    scoring='neg_log_loss', cv=3, n_jobs=6)

    search.fit(text, train.author)
    report(search.cv_results_)
    
    results = pd.DataFrame(search.cv_results_)
    save_filename = 'grid_search_results_' + str(time.time())
    print('Saving grid search results to', save_filename)
    results.to_csv(save_filename)

# %%
start_time = time.time()

params = {
    "features__ngram_range": [(1,1)],#, (1,2), (1,3)],
    "features__analyzer": ['word'],
    "features__max_df":[1.0, 0.9, 0.8, 0.7, 0.6, 0.5],
    "features__min_df":[1, 2, 3, 5, 10],
    "features__lowercase": [False, True],
    "features__stop_words": [None],
    "features__norm": ['l1', 'l2', None],
    "clf__alpha": [0.001, 0.005, 0.01, 0.05, 0.1, 0.3]
}

# grid_search(explore.stemmed, params)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.00010037422180175781 seconds ---

# %% [markdown]
# Much hope, no results.. За съжаление след много мъка не успях да подкарам Grid Search да се изпълни с толкова много параматри без да ми свърши RAM-та. Ще пробвам отново randomized search просто с повече итерации.

# %%
import time
from sklearn.model_selection import GridSearchCV
def random_search_with_save(text, params, n_iter):
    pipeline = Pipeline([
        ('features', TfidfVectorizer()),
        ('clf', MultinomialNB())
    ])

    search = RandomizedSearchCV(pipeline, param_distributions=params, 
                                    scoring='neg_log_loss', cv=3, n_jobs=6, n_iter=n_iter)

    search.fit(text, train.author)
    report(search.cv_results_)
    
    results = pd.DataFrame(search.cv_results_)
    save_filename = 'random_search_results_' + str(time.time())
    print('Saving random search results to', save_filename)
    results.to_csv(save_filename)

# %%
start_time = time.time()

params = {
    "features__ngram_range": [(1,1), (1,2), (1,3), (1,4), (1,5)],
    "features__analyzer": ['word'],
    "features__max_df":[1.0, 0.9, 0.8, 0.7, 0.6, 0.5],
    "features__min_df":[1, 2, 3, 5, 10],
    "features__lowercase": [False, True],
    "features__stop_words": [None],
    "features__norm": ['l1', 'l2', None],
    "clf__alpha": [0.001, 0.005, 0.01, 0.05, 0.1, 0.3]
}

for iteration in range(50):
    print('\n------------- ITERATION', iteration, '-------------')
    random_search_with_save(explore.stemmed, params, n_iter=20)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ------------- ITERATION 0 -------------
# Model with rank: 1
# Mean validation score: -0.405 (std: 0.002)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.477 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.486 (std: 0.002)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.527 (std: 0.001)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.570 (std: 0.014)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.001, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512419845.3117762
#
# ------------- ITERATION 1 -------------
# Model with rank: 1
# Mean validation score: -0.436 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.459 (std: 0.007)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.486 (std: 0.002)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.490 (std: 0.006)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 5
# Mean validation score: -0.535 (std: 0.002)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.1, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512419934.0794625
#
# ------------- ITERATION 2 -------------
# Model with rank: 1
# Mean validation score: -0.415 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.466 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.005, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.479 (std: 0.004)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.01, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 4
# Mean validation score: -0.523 (std: 0.004)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.001, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.775 (std: 0.001)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.001, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l1', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512419997.7525647
#
# ------------- ITERATION 3 -------------
# Model with rank: 1
# Mean validation score: -0.468 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.1, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 2
# Mean validation score: -0.471 (std: 0.003)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.01, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.486 (std: 0.006)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.005, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.487 (std: 0.005)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.525 (std: 0.000)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.01, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512420072.3636608
#
# ------------- ITERATION 4 -------------
# Model with rank: 1
# Mean validation score: -0.428 (std: 0.005)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.434 (std: 0.005)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 3
# Mean validation score: -0.439 (std: 0.004)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 4
# Mean validation score: -0.460 (std: 0.004)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.516 (std: 0.002)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.1, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512420142.566168
#
# ------------- ITERATION 5 -------------
# Model with rank: 1
# Mean validation score: -0.467 (std: 0.007)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 2
# Mean validation score: -0.497 (std: 0.003)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.3, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.515 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.3, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 4
# Mean validation score: -0.528 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.558 (std: 0.003)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.3, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Saving random search results to random_search_results_1512420208.1091692
#
# ------------- ITERATION 6 -------------
# Model with rank: 1
# Mean validation score: -0.438 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 2
# Mean validation score: -0.452 (std: 0.002)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.453 (std: 0.004)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.1, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.467 (std: 0.008)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.469 (std: 0.003)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512420281.4098012
#
# ------------- ITERATION 7 -------------
# Model with rank: 1
# Mean validation score: -0.472 (std: 0.004)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.05, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.495 (std: 0.003)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.3, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 3
# Mean validation score: -0.525 (std: 0.001)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.01, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.555 (std: 0.002)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.001, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.569 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.001, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512420363.9885669
#
# ------------- ITERATION 8 -------------
# Model with rank: 1
# Mean validation score: -0.405 (std: 0.002)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.435 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.437 (std: 0.002)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.458 (std: 0.004)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.467 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512420420.2865887
#
# ------------- ITERATION 9 -------------
# Model with rank: 1
# Mean validation score: -0.458 (std: 0.002)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 2
# Mean validation score: -0.496 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.3, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.516 (std: 0.003)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.3, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 4
# Mean validation score: -0.538 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.001, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 5
# Mean validation score: -0.559 (std: 0.011)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.001, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Saving random search results to random_search_results_1512420498.7104414
#
# ------------- ITERATION 10 -------------
# Model with rank: 1
# Mean validation score: -0.426 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.428 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 3
# Mean validation score: -0.464 (std: 0.008)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.486 (std: 0.005)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.005, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 5
# Mean validation score: -0.513 (std: 0.001)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.001, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512420574.864604
#
# ------------- ITERATION 11 -------------
# Model with rank: 1
# Mean validation score: -0.427 (std: 0.003)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.458 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.468 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 4
# Mean validation score: -0.470 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.1, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.472 (std: 0.004)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512420630.455193
#
# ------------- ITERATION 12 -------------
# Model with rank: 1
# Mean validation score: -0.439 (std: 0.004)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.480 (std: 0.005)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.01, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 3
# Mean validation score: -0.517 (std: 0.003)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.3, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 4
# Mean validation score: -0.520 (std: 0.006)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.001, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.524 (std: 0.001)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.01, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Saving random search results to random_search_results_1512420699.3653224
#
# ------------- ITERATION 13 -------------
# Model with rank: 1
# Mean validation score: -0.429 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 2
# Mean validation score: -0.439 (std: 0.004)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.444 (std: 0.005)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.05, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 4
# Mean validation score: -0.450 (std: 0.004)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.1, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 5
# Mean validation score: -0.468 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.1, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Saving random search results to random_search_results_1512420774.508695
#
# ------------- ITERATION 14 -------------
# Model with rank: 1
# Mean validation score: -0.430 (std: 0.002)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.1, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.437 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.477 (std: 0.002)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 4
# Mean validation score: -0.490 (std: 0.006)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.005, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 5
# Mean validation score: -0.525 (std: 0.002)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.3, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Saving random search results to random_search_results_1512420826.5620277
#
# ------------- ITERATION 15 -------------
# Model with rank: 1
# Mean validation score: -0.439 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 2
# Mean validation score: -0.459 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 3
# Mean validation score: -0.473 (std: 0.004)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.498 (std: 0.004)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.3, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.525 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.3, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512420899.384751
#
# ------------- ITERATION 16 -------------
# Model with rank: 1
# Mean validation score: -0.438 (std: 0.004)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.469 (std: 0.003)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.05, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.482 (std: 0.001)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.1, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.496 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.3, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.515 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.3, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Saving random search results to random_search_results_1512420971.3345535
#
# ------------- ITERATION 17 -------------
# Model with rank: 1
# Mean validation score: -0.457 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.478 (std: 0.002)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.479 (std: 0.004)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.01, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.515 (std: 0.001)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.001, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.524 (std: 0.005)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.001, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512421030.8666272
#
# ------------- ITERATION 18 -------------
# Model with rank: 1
# Mean validation score: -0.428 (std: 0.005)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.452 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.453 (std: 0.005)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.1, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 4
# Mean validation score: -0.477 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.1, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 5
# Mean validation score: -0.478 (std: 0.005)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.01, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Saving random search results to random_search_results_1512421106.8895547
#
# ------------- ITERATION 19 -------------
# Model with rank: 1
# Mean validation score: -0.426 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.435 (std: 0.006)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 3
# Mean validation score: -0.438 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.1, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.524 (std: 0.007)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.001, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.529 (std: 0.001)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.05, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Saving random search results to random_search_results_1512421181.746093
#
# ------------- ITERATION 20 -------------
# Model with rank: 1
# Mean validation score: -0.428 (std: 0.005)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.459 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 3
# Mean validation score: -0.479 (std: 0.002)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 4
# Mean validation score: -0.479 (std: 0.002)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.497 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.3, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512421258.0381026
#
# ------------- ITERATION 21 -------------
# Model with rank: 1
# Mean validation score: -0.497 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.3, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.521 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.01, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.523 (std: 0.002)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.3, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 4
# Mean validation score: -0.764 (std: 0.002)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l1', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.797 (std: 0.002)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.01, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l1', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512421330.0357177
#
# ------------- ITERATION 22 -------------
# Model with rank: 1
# Mean validation score: -0.445 (std: 0.004)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 2
# Mean validation score: -0.516 (std: 0.004)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.001, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.521 (std: 0.007)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.001, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 4
# Mean validation score: -0.524 (std: 0.007)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.001, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 5
# Mean validation score: -0.559 (std: 0.002)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.3, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Saving random search results to random_search_results_1512421415.0146568
#
# ------------- ITERATION 23 -------------
# Model with rank: 1
# Mean validation score: -0.416 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.01, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.440 (std: 0.004)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.05, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.484 (std: 0.005)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 4
# Mean validation score: -0.485 (std: 0.002)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.496 (std: 0.003)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.3, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Saving random search results to random_search_results_1512421467.3493965
#
# ------------- ITERATION 24 -------------
# Model with rank: 1
# Mean validation score: -0.422 (std: 0.003)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.438 (std: 0.004)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.450 (std: 0.004)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.1, 'features__min_df': 3, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 4
# Mean validation score: -0.468 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 5, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 5
# Mean validation score: -0.473 (std: 0.004)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.005, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Saving random search results to random_search_results_1512421525.1557882
#
# ------------- ITERATION 25 -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-974a13d80fe7> in <module>()
#      14 for iteration in range(50):
#      15     print('\n------------- ITERATION', iteration, '-------------')
# ---> 16     random_search_with_save(explore.stemmed, params, n_iter=20)
#      17
#      18 print("--- %s seconds ---" % (time.time() - start_time))
#
# <ipython-input-80-d270ec7eb7f3> in random_search_with_save(text, params, n_iter)
#      10                                     scoring='neg_log_loss', cv=3, n_jobs=6, n_iter=n_iter)
#      11
# ---> 12     search.fit(text, train.author)
#      13     report(search.cv_results_)
#      14
#
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     636                                   error_score=self.error_score)
#     637           for parameters, (train, test) in product(candidate_params,
# --> 638                                                    cv.split(X, y, groups)))
#     639
#     640         # if one choose to see train score, "out" will contain train score info
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /usr/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /usr/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
saved_results = pd.read_csv('random_search_results_1512419845.3117762')
report(saved_results)
# Out:
# Model with rank: 1
# Mean validation score: -0.405 (std: 0.002)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.477 (std: 0.002)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.486 (std: 0.002)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.005, 'features__min_df': 2, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}
#
# Model with rank: 4
# Mean validation score: -0.527 (std: 0.001)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.005, 'features__min_df': 10, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.570 (std: 0.014)
# Parameters: {'features__max_df': 0.9, 'clf__alpha': 0.001, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 5)}

# %% [markdown]
# Да пробваме с новонамерените най-добри параметри:

# %%
pipeline = Pipeline([
    ('features', TfidfVectorizer(ngram_range=(1, 2), min_df=1,
                                 max_df=0.9, lowercase=True, analyzer='word', norm='l2')),
    ('clf', MultinomialNB(alpha=0.05))
])

print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3))
print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3, 
                      scoring='neg_log_loss'))
# Out:
# [ 0.85217525  0.85228317  0.84934866]
# [-0.3919979  -0.39109396 -0.39412221]

# %% [markdown]
# Приятно подобрение. Имам нова идея за Grid Search, нека пробваме и нея и да събмитнем.

# %%
import time
from sklearn.model_selection import GridSearchCV
def grid_search(text, params):
    pipeline = Pipeline([
        ('features', TfidfVectorizer()),
        ('clf', MultinomialNB())
    ])

    search = GridSearchCV(pipeline, param_grid=params, 
                                    scoring='neg_log_loss', cv=3, n_jobs=6)

    search.fit(text, train.author)
#     report(search.cv_results_)
    
    results = pd.DataFrame(search.cv_results_)
    save_filename = 'grid_search_results_' + str(time.time())
    print('Saving grid search results to', save_filename)
    results.to_csv(save_filename)
    return results

# %%
import numpy as np

def report_best_of_all(results, n_top=5):
    results = results.sort_values(by='mean_test_score', ascending=False)
    candidates = results.head(5)
    for pos_best, (_, candidate) in enumerate(candidates.iterrows()):
        print("Model with rank: {0}".format(pos_best+1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
              candidate['mean_test_score'],
              candidate['std_test_score']))
        print("Parameters: {0}".format(candidate['params']))
        print("")

# %%
#with stemmed text
def grid_search_ngram_range(ngram_range):
    start_time = time.time()

    max_dfs = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5]
    min_dfs = [1, 2, 3, 5, 10]

    params = {
        "features__analyzer": ['word'],
        "features__lowercase": [False, True],
        "features__stop_words": [None],
        "features__norm": ['l1', 'l2', None],
        "clf__alpha": [0.001, 0.005, 0.01, 0.05, 0.1, 0.3, 1, 2]
    }

    results = []
    for max_df in max_dfs:
        for min_df in min_dfs:
            print(ngram_range, max_df, min_df)
            params["features__ngram_range"] = [ngram_range]
            params["features__max_df"] = [max_df]
            params["features__min_df"] = [min_df]
            result = grid_search(explore.stemmed, params)
            results.append(result)
            print("--- %s seconds ---" % (time.time() - start_time))

    results_concatenated = pd.concat(results, ignore_index=True)
    report_best_of_all(results_concatenated)

    print("--- %s seconds ---" % (time.time() - start_time))
    
grid_search_ngram_range((1,1))
# Out:
# (1, 1) 1.0 1
# Saving grid search results to grid_search_results_1512426187.9401221
# --- 36.0008704662323 seconds ---
# (1, 1) 1.0 2
# Saving grid search results to grid_search_results_1512426224.1731737
# --- 72.23167753219604 seconds ---
# (1, 1) 1.0 3
# Saving grid search results to grid_search_results_1512426260.9672508
# --- 109.02562808990479 seconds ---
# (1, 1) 1.0 5
# Saving grid search results to grid_search_results_1512426298.4766703
# --- 146.5349199771881 seconds ---
# (1, 1) 1.0 10
# Saving grid search results to grid_search_results_1512426334.6683414
# --- 182.7278757095337 seconds ---
# (1, 1) 0.9 1
# Saving grid search results to grid_search_results_1512426372.020266
# --- 220.07926058769226 seconds ---
# (1, 1) 0.9 2
# Saving grid search results to grid_search_results_1512426412.8781815
# --- 260.9392509460449 seconds ---
# (1, 1) 0.9 3
# Saving grid search results to grid_search_results_1512426455.9829326
# --- 304.04143500328064 seconds ---
# (1, 1) 0.9 5
# Saving grid search results to grid_search_results_1512426495.364257
# --- 343.4228277206421 seconds ---
# (1, 1) 0.9 10
# Saving grid search results to grid_search_results_1512426536.585985
# --- 384.6443531513214 seconds ---
# (1, 1) 0.8 1
# Saving grid search results to grid_search_results_1512426577.1928675
# --- 425.2510449886322 seconds ---
# (1, 1) 0.8 2
# Saving grid search results to grid_search_results_1512426619.797569
# --- 467.85877299308777 seconds ---
# (1, 1) 0.8 3
# Saving grid search results to grid_search_results_1512426663.0090861
# --- 511.0674967765808 seconds ---
# (1, 1) 0.8 5
# Saving grid search results to grid_search_results_1512426706.3179567
# --- 554.3805418014526 seconds ---
# (1, 1) 0.8 10
# Saving grid search results to grid_search_results_1512426746.9230616
# --- 594.9807901382446 seconds ---
# (1, 1) 0.7 1
# Saving grid search results to grid_search_results_1512426790.2607358
# --- 638.3192753791809 seconds ---
# (1, 1) 0.7 2
# Saving grid search results to grid_search_results_1512426832.5300949
# --- 680.5887372493744 seconds ---
# (1, 1) 0.7 3
# Saving grid search results to grid_search_results_1512426874.5144374
# --- 722.572817325592 seconds ---
# (1, 1) 0.7 5
# Saving grid search results to grid_search_results_1512426917.8305993
# --- 765.8893849849701 seconds ---
# (1, 1) 0.7 10
# Saving grid search results to grid_search_results_1512426959.2137778
# --- 807.2721080780029 seconds ---
# (1, 1) 0.6 1
# Saving grid search results to grid_search_results_1512427002.6697166
# --- 850.727810382843 seconds ---
# (1, 1) 0.6 2
# Saving grid search results to grid_search_results_1512427045.9122865
# --- 893.9716958999634 seconds ---
# (1, 1) 0.6 3
# Saving grid search results to grid_search_results_1512427085.0249796
# --- 933.0831522941589 seconds ---
# (1, 1) 0.6 5
# Saving grid search results to grid_search_results_1512427130.0543728
# --- 978.1127791404724 seconds ---
# (1, 1) 0.6 10
# Saving grid search results to grid_search_results_1512427172.8741932
# --- 1020.9342517852783 seconds ---
# (1, 1) 0.5 1
# Saving grid search results to grid_search_results_1512427214.351681
# --- 1062.4103231430054 seconds ---
# (1, 1) 0.5 2
# Saving grid search results to grid_search_results_1512427255.5695674
# --- 1103.6282515525818 seconds ---
# (1, 1) 0.5 3
# Saving grid search results to grid_search_results_1512427295.5702794
# --- 1143.6302618980408 seconds ---
# (1, 1) 0.5 5
# Saving grid search results to grid_search_results_1512427338.2990334
# --- 1186.3574035167694 seconds ---
# (1, 1) 0.5 10
# Saving grid search results to grid_search_results_1512427376.6121168
# --- 1224.6704869270325 seconds ---
# Model with rank: 1
# Mean validation score: -0.454 (std: 0.003)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 2
# Mean validation score: -0.454 (std: 0.003)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 3
# Mean validation score: -0.454 (std: 0.003)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 4
# Mean validation score: -0.455 (std: 0.004)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# Model with rank: 5
# Mean validation score: -0.455 (std: 0.003)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 1)}
#
# --- 1224.6829965114594 seconds ---

# %%
grid_search_ngram_range((1,2))
# Out:
# (1, 2) 1.0 1
# Saving grid search results to grid_search_results_1512427479.4382575
# --- 102.81932425498962 seconds ---
# (1, 2) 1.0 2
# Saving grid search results to grid_search_results_1512427573.6548686
# --- 197.033766746521 seconds ---
# (1, 2) 1.0 3
# Saving grid search results to grid_search_results_1512427662.6019924
# --- 285.9807765483856 seconds ---
# (1, 2) 1.0 5
# Saving grid search results to grid_search_results_1512427750.6143012
# --- 373.99206256866455 seconds ---
# (1, 2) 1.0 10
# Saving grid search results to grid_search_results_1512427837.7832794
# --- 461.1602518558502 seconds ---
# (1, 2) 0.9 1
# Saving grid search results to grid_search_results_1512427936.3800635
# --- 559.7603869438171 seconds ---
# (1, 2) 0.9 2
# Saving grid search results to grid_search_results_1512428028.11338
# --- 651.4921116828918 seconds ---
# (1, 2) 0.9 3
# Saving grid search results to grid_search_results_1512428122.067634
# --- 745.4462003707886 seconds ---
# (1, 2) 0.9 5
# Saving grid search results to grid_search_results_1512428218.2187598
# --- 841.5957746505737 seconds ---
# (1, 2) 0.9 10
# Saving grid search results to grid_search_results_1512428313.669499
# --- 937.0468761920929 seconds ---
# (1, 2) 0.8 1
# Saving grid search results to grid_search_results_1512428418.885046
# --- 1042.266892671585 seconds ---
# (1, 2) 0.8 2
# Saving grid search results to grid_search_results_1512428518.9766502
# --- 1142.3557271957397 seconds ---
# (1, 2) 0.8 3
# Saving grid search results to grid_search_results_1512428621.5260096
# --- 1244.9084241390228 seconds ---
# (1, 2) 0.8 5
# Saving grid search results to grid_search_results_1512428715.1046362
# --- 1338.4824848175049 seconds ---
# (1, 2) 0.8 10
# Saving grid search results to grid_search_results_1512428809.9814577
# --- 1433.3604822158813 seconds ---
# (1, 2) 0.7 1
# Saving grid search results to grid_search_results_1512428916.8761935
# --- 1540.258674621582 seconds ---
# (1, 2) 0.7 2
# Saving grid search results to grid_search_results_1512429013.71503
# --- 1637.0939569473267 seconds ---
# (1, 2) 0.7 3
# Saving grid search results to grid_search_results_1512429113.7929807
# --- 1737.1722495555878 seconds ---
# (1, 2) 0.7 5
# Saving grid search results to grid_search_results_1512429211.9316213
# --- 1835.309770822525 seconds ---
# (1, 2) 0.7 10
# Saving grid search results to grid_search_results_1512429350.3063042
# --- 1973.6836359500885 seconds ---
# (1, 2) 0.6 1
# Saving grid search results to grid_search_results_1512429455.0412118
# --- 2078.423972606659 seconds ---
# (1, 2) 0.6 2
# Saving grid search results to grid_search_results_1512429544.452261
# --- 2167.8302454948425 seconds ---
# (1, 2) 0.6 3
# Saving grid search results to grid_search_results_1512429636.363046
# --- 2259.741313934326 seconds ---
# (1, 2) 0.6 5
# Saving grid search results to grid_search_results_1512429724.3975058
# --- 2347.7744896411896 seconds ---
# (1, 2) 0.6 10
# Saving grid search results to grid_search_results_1512429805.769513
# --- 2429.1458570957184 seconds ---
# (1, 2) 0.5 1
# Saving grid search results to grid_search_results_1512429896.939395
# --- 2520.319880962372 seconds ---
# (1, 2) 0.5 2
# Saving grid search results to grid_search_results_1512429981.7508118
# --- 2605.127665758133 seconds ---
# (1, 2) 0.5 3
# Saving grid search results to grid_search_results_1512430066.1500976
# --- 2689.5280854701996 seconds ---
# (1, 2) 0.5 5
# Saving grid search results to grid_search_results_1512430149.7031896
# --- 2773.0798857212067 seconds ---
# (1, 2) 0.5 10
# Saving grid search results to grid_search_results_1512430229.7849078
# --- 2853.160580635071 seconds ---
# Model with rank: 1
# Mean validation score: -0.405 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 2
# Mean validation score: -0.405 (std: 0.002)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 3
# Mean validation score: -0.405 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 4
# Mean validation score: -0.405 (std: 0.001)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# Model with rank: 5
# Mean validation score: -0.405 (std: 0.002)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 2)}
#
# --- 2853.1717636585236 seconds ---

# %%
grid_search_ngram_range((1,3))
# Out:
# (1, 3) 1.0 1
# Saving grid search results to grid_search_results_1512430400.1583655
# --- 170.4003357887268 seconds ---
# (1, 3) 1.0 2
# Saving grid search results to grid_search_results_1512430551.652627
# --- 321.8888840675354 seconds ---
# (1, 3) 1.0 3
# Saving grid search results to grid_search_results_1512430699.217702
# --- 469.44824028015137 seconds ---
# (1, 3) 1.0 5
# Saving grid search results to grid_search_results_1512430843.3834398
# --- 613.6137456893921 seconds ---
# (1, 3) 1.0 10
# Saving grid search results to grid_search_results_1512430991.1406446
# --- 761.3688488006592 seconds ---
# (1, 3) 0.9 1
# Saving grid search results to grid_search_results_1512431162.1948178
# --- 932.4381420612335 seconds ---
# (1, 3) 0.9 2
# Saving grid search results to grid_search_results_1512431315.9268553
# --- 1086.1584510803223 seconds ---
# (1, 3) 0.9 3
# Saving grid search results to grid_search_results_1512431465.4162474
# --- 1235.6493589878082 seconds ---
# (1, 3) 0.9 5
# Saving grid search results to grid_search_results_1512431617.5049777
# --- 1387.7348310947418 seconds ---
# (1, 3) 0.9 10
# Saving grid search results to grid_search_results_1512431765.2666333
# --- 1535.4981026649475 seconds ---
# (1, 3) 0.8 1
# Saving grid search results to grid_search_results_1512431936.2106209
# --- 1706.451332807541 seconds ---
# (1, 3) 0.8 2
# Saving grid search results to grid_search_results_1512432089.442787
# --- 1859.6771619319916 seconds ---
# (1, 3) 0.8 3
# Saving grid search results to grid_search_results_1512432241.0067403
# --- 2011.237956047058 seconds ---
# (1, 3) 0.8 5
# Saving grid search results to grid_search_results_1512432391.2371058
# --- 2161.468340396881 seconds ---
# (1, 3) 0.8 10
# Saving grid search results to grid_search_results_1512432541.5815544
# --- 2311.808535337448 seconds ---
# (1, 3) 0.7 1
# Saving grid search results to grid_search_results_1512432713.6176302
# --- 2483.860423564911 seconds ---
# (1, 3) 0.7 2
# Saving grid search results to grid_search_results_1512432869.7894614
# --- 2640.0229461193085 seconds ---
# (1, 3) 0.7 3
# Saving grid search results to grid_search_results_1512433020.440688
# --- 2790.6732296943665 seconds ---
# (1, 3) 0.7 5
# Saving grid search results to grid_search_results_1512433170.7916734
# --- 2941.020810842514 seconds ---
# (1, 3) 0.7 10
# Saving grid search results to grid_search_results_1512433320.3402464
# --- 3090.570953130722 seconds ---
# (1, 3) 0.6 1
# Saving grid search results to grid_search_results_1512433495.242519
# --- 3265.4799795150757 seconds ---
# (1, 3) 0.6 2
# Saving grid search results to grid_search_results_1512433647.8604877
# --- 3418.0926942825317 seconds ---
# (1, 3) 0.6 3
# Saving grid search results to grid_search_results_1512433800.2534406
# --- 3570.4818816184998 seconds ---
# (1, 3) 0.6 5
# Saving grid search results to grid_search_results_1512433951.1321938
# --- 3721.365641117096 seconds ---
# (1, 3) 0.6 10
# Saving grid search results to grid_search_results_1512434098.4912076
# --- 3868.718095779419 seconds ---
# (1, 3) 0.5 1
# Saving grid search results to grid_search_results_1512434272.7992666
# --- 4043.042800426483 seconds ---
# (1, 3) 0.5 2
# Saving grid search results to grid_search_results_1512434426.5862114
# --- 4196.816658735275 seconds ---
# (1, 3) 0.5 3
# Saving grid search results to grid_search_results_1512434577.6343963
# --- 4347.867666244507 seconds ---
# (1, 3) 0.5 5
# Saving grid search results to grid_search_results_1512434730.4083097
# --- 4500.638806819916 seconds ---
# (1, 3) 0.5 10
# Saving grid search results to grid_search_results_1512434879.4984784
# --- 4649.7297303676605 seconds ---
# Model with rank: 1
# Mean validation score: -0.415 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 2
# Mean validation score: -0.415 (std: 0.001)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 3
# Mean validation score: -0.415 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 4
# Mean validation score: -0.415 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# Model with rank: 5
# Mean validation score: -0.415 (std: 0.001)
# Parameters: {'features__max_df': 1.0, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 3)}
#
# --- 4649.76383972168 seconds ---

# %%
grid_search_ngram_range((1,4))
# Out:
# (1, 4) 1.0 1
# Saving grid search results to grid_search_results_1512435135.7461748
# --- 256.1924467086792 seconds ---
# (1, 4) 1.0 2
# Saving grid search results to grid_search_results_1512435363.124219
# --- 483.54827761650085 seconds ---
# (1, 4) 1.0 3
# Saving grid search results to grid_search_results_1512435591.3487787
# --- 711.7688000202179 seconds ---
# (1, 4) 1.0 5
# Saving grid search results to grid_search_results_1512435812.0980244
# --- 932.5234990119934 seconds ---
# (1, 4) 1.0 10
# Saving grid search results to grid_search_results_1512436035.761526
# --- 1156.1834888458252 seconds ---
# (1, 4) 0.9 1
# Saving grid search results to grid_search_results_1512436298.6903434
# --- 1419.133519411087 seconds ---
# (1, 4) 0.9 2
# Saving grid search results to grid_search_results_1512436525.4579515
# --- 1645.888031721115 seconds ---
# (1, 4) 0.9 3
# Saving grid search results to grid_search_results_1512436750.4521673
# --- 1870.8701527118683 seconds ---
# (1, 4) 0.9 5
# Saving grid search results to grid_search_results_1512436973.7919085
# --- 2094.213833808899 seconds ---
# (1, 4) 0.9 10
# Saving grid search results to grid_search_results_1512437196.7910714
# --- 2317.2128562927246 seconds ---
# (1, 4) 0.8 1
# Saving grid search results to grid_search_results_1512437458.8427448
# --- 2579.2870349884033 seconds ---
# (1, 4) 0.8 2
# Saving grid search results to grid_search_results_1512437688.6242728
# --- 2809.0513513088226 seconds ---
# (1, 4) 0.8 3
# Saving grid search results to grid_search_results_1512437918.2800438
# --- 3038.7012515068054 seconds ---
# (1, 4) 0.8 5
# Saving grid search results to grid_search_results_1512438142.9356158
# --- 3263.3561182022095 seconds ---
# (1, 4) 0.8 10
# Saving grid search results to grid_search_results_1512438366.543669
# --- 3486.968509197235 seconds ---
# (1, 4) 0.7 1
# Saving grid search results to grid_search_results_1512438625.3302085
# --- 3745.7709879875183 seconds ---
# (1, 4) 0.7 2
# Saving grid search results to grid_search_results_1512438855.7968268
# --- 3976.2224414348602 seconds ---
# (1, 4) 0.7 3
# Saving grid search results to grid_search_results_1512439082.2858045
# --- 4202.716916799545 seconds ---
# (1, 4) 0.7 5
# Saving grid search results to grid_search_results_1512439307.4506874
# --- 4427.866633892059 seconds ---
# (1, 4) 0.7 10
# Saving grid search results to grid_search_results_1512439533.396209
# --- 4653.822162389755 seconds ---
# (1, 4) 0.6 1
# Saving grid search results to grid_search_results_1512439795.8310347
# --- 4916.279571533203 seconds ---
# (1, 4) 0.6 2
# Saving grid search results to grid_search_results_1512440021.7889402
# --- 5142.219447374344 seconds ---
# (1, 4) 0.6 3
# Saving grid search results to grid_search_results_1512440248.9630873
# --- 5369.38326382637 seconds ---
# (1, 4) 0.6 5
# Saving grid search results to grid_search_results_1512440472.0824902
# --- 5592.508627653122 seconds ---
# (1, 4) 0.6 10
# Saving grid search results to grid_search_results_1512440691.3269913
# --- 5811.745666742325 seconds ---
# (1, 4) 0.5 1
# Saving grid search results to grid_search_results_1512440953.7316995
# --- 6074.1765995025635 seconds ---
# (1, 4) 0.5 2
# Saving grid search results to grid_search_results_1512441180.9057639
# --- 6301.330704212189 seconds ---
# (1, 4) 0.5 3
# Saving grid search results to grid_search_results_1512441407.1056352
# --- 6527.534911870956 seconds ---
# (1, 4) 0.5 5
# Saving grid search results to grid_search_results_1512441630.9375944
# --- 6751.357619524002 seconds ---
# (1, 4) 0.5 10
# Saving grid search results to grid_search_results_1512441851.360011
# --- 6971.784264326096 seconds ---
# Model with rank: 1
# Mean validation score: -0.427 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 2
# Mean validation score: -0.427 (std: 0.001)
# Parameters: {'features__max_df': 0.6, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 3
# Mean validation score: -0.427 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 4
# Mean validation score: -0.427 (std: 0.002)
# Parameters: {'features__max_df': 0.5, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': False, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# Model with rank: 5
# Mean validation score: -0.428 (std: 0.001)
# Parameters: {'features__max_df': 0.8, 'clf__alpha': 0.05, 'features__min_df': 1, 'features__stop_words': None, 'features__norm': 'l2', 'features__lowercase': True, 'features__analyzer': 'word', 'features__ngram_range': (1, 4)}
#
# --- 6971.809899091721 seconds ---

# %%
grid_search_ngram_range((1,5))
# Out:
# (1, 5) 1.0 1

# %%
pipeline = Pipeline([
    ('features', TfidfVectorizer(ngram_range=(1, 2), min_df=1,
                                 max_df=0.5, lowercase=False, analyzer='word', norm='l2')),
    ('clf', MultinomialNB(alpha=0.05))
])

print(cross_val_score(pipeline, explore.stemmed, train.author, cv=3, n_jobs=3))
print(cross_val_score(pipeline, explore.stemmed, train.author, cv=3, n_jobs=3, 
                      scoring='neg_log_loss'))
# Out:
# [ 0.83992034  0.84600061  0.84229885]
# [-0.40539568 -0.40318401 -0.40505574]

# %%
def grid_search_ngram_range_original_text(ngram_range):
    start_time = time.time()

    max_dfs = [1.0, 0.9, 0.8, 0.7, 0.6, 0.5]
    min_dfs = [1, 2, 3]

    params = {
        "features__analyzer": ['word'],
        "features__lowercase": [False, True],
        "features__stop_words": [None],
        "features__norm": ['l2'],
        "clf__alpha": [0.001, 0.005, 0.01, 0.05, 0.1, 0.3, 1]
    }

    results = []
    for max_df in max_dfs:
        for min_df in min_dfs:
            print(ngram_range, max_df, min_df)
            params["features__ngram_range"] = [ngram_range]
            params["features__max_df"] = [max_df]
            params["features__min_df"] = [min_df]
            result = grid_search(train.text, params)
            results.append(result)
            print("--- %s seconds ---" % (time.time() - start_time))

    results_concatenated = pd.concat(results, ignore_index=True)
    report_best_of_all(results_concatenated)

    print("--- %s seconds ---" % (time.time() - start_time))
    
grid_search_ngram_range_original_text((1,2))
# Out:
# (1, 2) 1.0 1
# Saving grid search results to grid_search_results_1512480129.0763836
# --- 63.37544131278992 seconds ---
# (1, 2) 1.0 2
# Saving grid search results to grid_search_results_1512480188.0675588
# --- 122.40183138847351 seconds ---
# (1, 2) 1.0 3
# Saving grid search results to grid_search_results_1512480243.3354244
# --- 177.6348433494568 seconds ---
# (1, 2) 0.9 1
# Saving grid search results to grid_search_results_1512480305.0062802
# --- 239.3092577457428 seconds ---
# (1, 2) 0.9 2
# Saving grid search results to grid_search_results_1512480364.1854217
# --- 298.52094650268555 seconds ---
# (1, 2) 0.9 3
# Saving grid search results to grid_search_results_1512480423.2814221
# --- 357.57992911338806 seconds ---
# (1, 2) 0.8 1
# Saving grid search results to grid_search_results_1512480484.8736901
# --- 419.17773509025574 seconds ---
# (1, 2) 0.8 2
# Saving grid search results to grid_search_results_1512480544.3826375
# --- 478.6832025051117 seconds ---
# (1, 2) 0.8 3
# Saving grid search results to grid_search_results_1512480599.011196
# --- 533.3439953327179 seconds ---
# (1, 2) 0.7 1
# Saving grid search results to grid_search_results_1512480664.8165185
# --- 599.1190989017487 seconds ---
# (1, 2) 0.7 2
# Saving grid search results to grid_search_results_1512480724.9411511
# --- 659.2400298118591 seconds ---
# (1, 2) 0.7 3
# Saving grid search results to grid_search_results_1512480782.1406784
# --- 716.4751651287079 seconds ---
# (1, 2) 0.6 1
# Saving grid search results to grid_search_results_1512480845.9626365
# --- 780.2655081748962 seconds ---
# (1, 2) 0.6 2
# Saving grid search results to grid_search_results_1512480904.7714624
# --- 839.1074481010437 seconds ---
# (1, 2) 0.6 3
# Saving grid search results to grid_search_results_1512480962.8293211
# --- 897.1610615253448 seconds ---
# (1, 2) 0.5 1
# Saving grid search results to grid_search_results_1512481024.5516145
# --- 958.8812592029572 seconds ---
# (1, 2) 0.5 2
# Saving grid search results to grid_search_results_1512481085.331962
# --- 1019.6672780513763 seconds ---
# (1, 2) 0.5 3
# Saving grid search results to grid_search_results_1512481142.5590875
# --- 1076.8946390151978 seconds ---
# Model with rank: 1
# Mean validation score: -0.390 (std: 0.001)
# Parameters: {'features__max_df': 0.5, 'features__stop_words': None, 'features__min_df': 1, 'features__ngram_range': (1, 2), 'features__lowercase': False, 'features__norm': 'l2', 'features__analyzer': 'word', 'clf__alpha': 0.05}
#
# Model with rank: 2
# Mean validation score: -0.390 (std: 0.001)
# Parameters: {'features__max_df': 0.7, 'features__stop_words': None, 'features__min_df': 1, 'features__ngram_range': (1, 2), 'features__lowercase': False, 'features__norm': 'l2', 'features__analyzer': 'word', 'clf__alpha': 0.05}
#
# Model with rank: 3
# Mean validation score: -0.390 (std: 0.001)
# Parameters: {'features__max_df': 0.6, 'features__stop_words': None, 'features__min_df': 1, 'features__ngram_range': (1, 2), 'features__lowercase': False, 'features__norm': 'l2', 'features__analyzer': 'word', 'clf__alpha': 0.05}
#
# Model with rank: 4
# Mean validation score: -0.390 (std: 0.001)
# Parameters: {'features__max_df': 0.8, 'features__stop_words': None, 'features__min_df': 1, 'features__ngram_range': (1, 2), 'features__lowercase': False, 'features__norm': 'l2', 'features__analyzer': 'word', 'clf__alpha': 0.05}
#
# Model with rank: 5
# Mean validation score: -0.390 (std: 0.001)
# Parameters: {'features__max_df': 0.9, 'features__stop_words': None, 'features__min_df': 1, 'features__ngram_range': (1, 2), 'features__lowercase': False, 'features__norm': 'l2', 'features__analyzer': 'word', 'clf__alpha': 0.05}
#
# --- 1076.9247980117798 seconds ---

# %%
pipeline = Pipeline([
    ('features', TfidfVectorizer(ngram_range=(1, 2), min_df=1,
                                 max_df=0.5, lowercase=False, analyzer='word', norm='l2')),
    ('clf', MultinomialNB(alpha=0.05))
])

print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3))
print(cross_val_score(pipeline, train.text, train.author, cv=3, n_jobs=3, 
                      scoring='neg_log_loss'))
# Out:
# [ 0.85416667  0.85335581  0.8502682 ]
# [-0.38995613 -0.38833216 -0.39106993]

# %% [markdown]
# Получихме същите параметри и дори по-добър резултат.

# %%
pipeline = pipeline.fit(train.text, train.author)

# %%
test_predictions = pipeline.predict_proba(test.text)

# %%
pipeline.classes_
# Out:
# array(['EAP', 'HPL', 'MWS'],
#       dtype='<U3')

# %%
submit_file = pd.DataFrame(test_predictions, columns=['EAP', 'HPL', 'MWS'], index=test.index)
submit_file.head(10)
# Out:
#               EAP       HPL       MWS
# id
# id02310  0.085998  0.009646  0.904357
# id24541  0.946239  0.040561  0.013199
# id00134  0.025347  0.963843  0.010810
# id27757  0.693222  0.293976  0.012802
# id04081  0.694155  0.202899  0.102946
# id27337  0.972891  0.026107  0.001002
# id24265  0.956902  0.027761  0.015337
# id25917  0.016713  0.046692  0.936595
# id04951  0.991779  0.007960  0.000261
# id14549  0.647427  0.189868  0.162704

# %%
submit_file.to_csv("predictions.csv")
